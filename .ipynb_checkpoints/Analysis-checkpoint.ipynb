# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('ggplot')

import pandas_datareader as web
import datetime
import mplfinance as mpf

# %% [markdown]
# Analyzing Gamestop Data

# %%
# importing data
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2020-12-10  14.41  13.05  13.12  14.12   7558900      14.12
# 2020-12-11  14.00  13.02  13.91  13.31   7496900      13.31
# 2020-12-14  13.43  12.14  13.34  12.72  10007100      12.72
# 2020-12-15  14.02  12.48  12.78  13.85   8192900      13.85
# 2020-12-16  14.31  13.58  13.96  13.85   5865100      13.85

# %%
# visualization
date = data_gme.index
adj_close = data_gme['Adj Close']

fig = plt.figure(figsize=(12,6))
plt.plot(date, adj_close, c='r')
plt.title('GameStop Adj Close Price')
plt.show()

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']

# %%
# candlestick chart
colors = mpf.make_marketcolors(up='palegreen',
                              down='cyan',
                              wick='inherit',
                              edge='inherit',
                              volume='in')

mpf_style = mpf.make_mpf_style(base_mpf_style='mike', marketcolors=colors)
mpf.plot(data_gme, type='candle', style=mpf_style, volume=True)
